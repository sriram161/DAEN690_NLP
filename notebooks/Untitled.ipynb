# %%
import nltk
import yaml
import pandas as pd

# %%
with open('C:/Users/notme/Documents/Development/DAEN690_NPL/data.yml', 'r') as infile:
    word_lists = yaml.load(infile)

# %%
df = pd.read_csv('C:/Users/notme/Documents/Development/DAEN690_NPL/clean_data.csv')

# %%
df.columns = ['row', 'sent']

# %%
df['sent']
# Out:
#        row                                               sent
# 0        0  baidu form strategic partnership qualcomm opti...
# 1        1  blackbaud announce result commission total eco...
# 2        2  earn per fully dilute ads gaap basis first qua...
# 3        3  fortescue current director operations greg lil...
# 4        4  gaap net loss third fiscal quarter million per...
# 5        5  issue common share exercise warrant vn capital...
# 6        6  launch seo wiz power search optimization wix s...
# 7        7  macquarie say still likely australian regulato...
# 8        8  bad news expect myer citi predict roughly perc...
# 9        9  secure new m credit facility comerica bank com...
# 10      10  successful renewal key strategic agreements lo...
# 11      11  continue strong organic volume growth speciali...
# 12      12  dis pixar walt disney animation studios say me...
# 13      13  flxn share surge percent afternoon trade frida...
# ...
